# %% [markdown]
# 假设我开了家淘宝服装店，平均每周卖出10件衣服，请问我应该保持的最佳库存量是多少？
#
# 假定不存在季节以及促销因素，可以近似认为，该问题满足以下三个条件：
#
# + 顾客购买是小概率事件
# + 购买顾客之间是独立的，也即不会互相依赖或者影响
# + 顾客购买的概率是稳定的

# %%
import scipy.stats as stats
[(stats.poisson.pmf(i,mu=10), stats.poisson.cdf(i,mu=10)) for i in range(20)]
# Out:
# [(4.5399929762484854e-05, 4.5399929762484861e-05),
#  (0.00045399929762484861, 0.00049939922738733355),
#  (0.0022699964881242435, 0.0027693957155115775),
#  (0.007566654960414144, 0.010336050675925726),
#  (0.018916637401035379, 0.029252688076961124),
#  (0.037833274802070792, 0.067085962879031888),
#  (0.063055458003451248, 0.13014142088248301),
#  (0.090079225719216005, 0.22022064660169924),
#  (0.11259903214902009, 0.33281967875071966),
#  (0.12511003572113372, 0.45792971447185427),
#  (0.12511003572113372, 0.58303975019298493),
#  (0.11373639611012128, 0.69677614630310614),
#  (0.094780330091768034, 0.79155647639487325),
#  (0.072907946224437067, 0.86446442261931056),
#  (0.052077104446026153, 0.91654152706533687),
#  (0.034718069630684245, 0.95125959669602123),
#  (0.021698793519177594, 0.97295839021519892),
#  (0.012763996187751505, 0.98572238640295029),
#  (0.0070911089931953337, 0.99281349539614561),
#  (0.0037321626279975288, 0.99654565802414319)]
