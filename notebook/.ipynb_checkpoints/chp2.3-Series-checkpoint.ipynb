# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series

# %% [markdown]
# **Series** 是pandas中的两种基础数据结构之一，可以理解为<i>一维带标签数组</i>.
#
# + 数组中数据可以为任意类型(整数，字符串，浮点数，Python objects等).
# + 数组中数据为同一类型(homogeneous)

# %% [markdown]
# ### 创建Series

# %% [markdown]
# 建立一个Series
#     - s = pd.Series(data, index=index)
#
# 这里data可以是
#
#     - list
#     - array
#     - dictionary

# %%
price = pd.Series([15280,45888,15692,55689,28410,27566])
price
# Out:
# 0    15280
# 1    45888
# 2    15692
# 3    55689
# 4    28410
# 5    27566
# dtype: int64

# %%
type(price)
# Out:
# pandas.core.series.Series

# %%
price = pd.Series([15280,45888,15692,55689,28410,27566],name="price")
price
# Out:
# 0    15280
# 1    45888
# 2    15692
# 3    55689
# 4    28410
# 5    27566
# Name: price, dtype: int64

# %%
pd.Series?

# %%
temp = {'Mon': 33, 'Tue': 19, 'Wed': 15, 'Thu': 89, 'Fri': 11, 'Sat': -5, 'Sun': 9}
pd.Series(temp)
# Out:
# Fri    11
# Mon    33
# Sat    -5
# Sun     9
# Thu    89
# Tue    19
# Wed    15
# dtype: int64

# %%
price.mean()
# Out:
# 31420.833333333332

# %%
price.sum()
# Out:
# 188525

# %%
price.head(2)
# Out:
# 0    15280
# 1    45888
# dtype: int64

# %%
price.tail(3)
# Out:
# 3    55689
# 4    28410
# 5    27566
# Name: price, dtype: int64

# %%
price.max?

# %%
print(dir(price))
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_SLICEMAP', '__abs__', '__add__', '__and__', '__array__', '__array_prepare__', '__array_priority__', '__array_wrap__', '__bool__', '__bytes__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__int__', '__invert__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__le__', '__len__', '__long__', '__lt__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__unicode__', '__weakref__', '__xor__', '_accessors', '_add_numeric_operations', '_add_series_only_operations', '_add_series_or_dataframe_operations', '_agg_by_level', '_align_frame', '_align_series', '_allow_index_ops', '_at', '_binop', '_box_item_values', '_can_hold_na', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_percentile', '_check_setitem_copy', '_clear_item_cache', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_dict_for_slice', '_construct_axes_dict_from', '_construct_axes_from_arguments', '_constructor', '_constructor_expanddim', '_constructor_sliced', '_convert', '_create_indexer', '_dir_additions', '_dir_deletions', '_expand_axes', '_from_axes', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_index_resolvers', '_get_item_cache', '_get_numeric_data', '_get_repr', '_get_values', '_get_values_tuple', '_get_with', '_iat', '_iget_item_cache', '_iloc', '_index', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_mgr', '_internal_names', '_internal_names_set', '_is_cached', '_is_datelike_mixed_type', '_is_mixed_type', '_is_numeric_mixed_type', '_is_view', '_ix', '_ixs', '_loc', '_make_cat_accessor', '_make_dt_accessor', '_make_str_accessor', '_maybe_cache_changed', '_maybe_update_cacher', '_metadata', '_needs_reindex_multi', '_protect_consolidate', '_reduce', '_reindex_axes', '_reindex_axis', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_is_copy', '_set_item', '_set_labels', '_set_name', '_set_subtyp', '_set_values', '_set_with', '_set_with_engine', '_setup_axes', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_typ', '_unpickle_series_compat', '_update_inplace', '_validate_dtype', '_values', '_xs', 'abs', 'add', 'add_prefix', 'add_suffix', 'align', 'all', 'any', 'append', 'apply', 'argmax', 'argmin', 'argsort', 'as_blocks', 'as_matrix', 'asfreq', 'asobject', 'asof', 'astype', 'at', 'at_time', 'autocorr', 'axes', 'base', 'between', 'between_time', 'bfill', 'blocks', 'bool', 'clip', 'clip_lower', 'clip_upper', 'combine', 'combine_first', 'compound', 'compress', 'consolidate', 'convert_objects', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'data', 'describe', 'diff', 'div', 'divide', 'dot', 'drop', 'drop_duplicates', 'dropna', 'dtype', 'dtypes', 'duplicated', 'empty', 'eq', 'equals', 'ewm', 'expanding', 'factorize', 'ffill', 'fillna', 'filter', 'first', 'first_valid_index', 'flags', 'floordiv', 'from_array', 'from_csv', 'ftype', 'ftypes', 'ge', 'get', 'get_dtype_counts', 'get_ftype_counts', 'get_value', 'get_values', 'groupby', 'gt', 'hasnans', 'head', 'hist', 'iat', 'idxmax', 'idxmin', 'iget', 'iget_value', 'iloc', 'im ...

# %% [markdown]
# #### data types in series

# %%
price = pd.Series([15280,45888,15692,55689,28410,27566])
price.dtype
# Out:
# dtype('int64')

# %%
price = pd.Series([15280,45888,15692,55689,28410,27566.3])
price.dtype
# Out:
# dtype('float64')

# %%
city=pd.Series(['wh','sh','hz','bj','gz','nj'])
city.dtype
# Out:
# dtype('O')

# %%
temp=pd.Series([{},[],(3,4)])
temp.dtype
# Out:
# dtype('O')

# %%
x=pd.Series(['2016-01-01','2017-01-01'])
print(x.dtype)
pd.to_datetime(x)
# Out:
# object
# 0   2016-01-01
# 1   2017-01-01
# dtype: datetime64[ns]

# %%
x=pd.Series(['hw','apple','vivo','mi','hw','oppo','samsung','vivo'],dtype='category')
x
# Out:
# 0         hw
# 1      apple
# 2       vivo
# 3         mi
# 4         hw
# 5       oppo
# 6    samsung
# 7       vivo
# dtype: category
# Categories (6, object): [apple, hw, mi, oppo, samsung, vivo]

# %% [markdown]
# #### boolean

# %%
mask=pd.Series([True,False,True,True,False,False])
mask
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
price
# Out:
# 0    15280.0
# 1    45888.0
# 2    15692.0
# 3    55689.0
# 4    28410.0
# 5    27566.3
# dtype: float64

# %%
price[mask]
# Out:
# 0    15280.0
# 2    15692.0
# 3    35689.0
# dtype: float64

# %%
mask2=pd.Series([True,False,True,True,False,True])
mask|mask2
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
mask&mask2
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
~mask
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
price>20000&price<30000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     784         try:
# --> 785             result = op(x, y)
#     786         except TypeError:
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\ops.py in <lambda>(x, y)
#     118                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 119                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     120                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     802                         y = bool(y)
# --> 803                     result = lib.scalar_binop(x, y, op)
#     804                 except:
#
# pandas\lib.pyx in pandas.lib.scalar_binop (pandas\lib.c:15524)()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'double'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-08de5e731692> in <module>()
# ----> 1 price>20000&price<30000
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#     834                       is_integer_dtype(np.asarray(other)) else fill_bool)
#     835             return filler(self._constructor(
# --> 836                 na_op(self.values, other),
#     837                 index=self.index)).__finalize__(self)
#     838
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     805                     raise TypeError("cannot compare a dtyped [{0}] array with "
#     806                                     "a scalar of type [{1}]".format(
# --> 807                                         x.dtype, type(y).__name__))
#     808
#     809         return result
#
# TypeError: cannot compare a dtyped [float64] array with a scalar of type [bool]

# %%
price[(price>20000)&(price<30000)]
# Out:
# 4    28410.0
# 5    27566.3
# dtype: float64

# %%
temp=[True,False,True,True,False,False]
temp2=[True,False,True,True,False,False]
temp & temp2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3b20f63a94b2> in <module>()
#       1 temp=[True,False,True,True,False,False]
#       2 temp2=[True,False,True,True,False,False]
# ----> 3 temp & temp2
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %% [markdown]
# #### index

# %%
price
# Out:
# 0    15280.0
# 1    45888.0
# 2    15692.0
# 3    55689.0
# 4    28410.0
# 5    27566.3
# dtype: float64

# %%
price[2]
# Out:
# 15692.0

# %%
price = pd.Series([15280,45888,15692,55689,28410,27566.3],index=['wh','sh','hz','bj','gz','nj'])
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
price['sh']
# Out:
# 45888.0

# %%
price.index
# Out:
# Index(['wh', 'sh', 'hz', 'bj', 'gz', 'nj'], dtype='object')

# %%
price.index.name='city'
price
# Out:
# city
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
dates=pd.date_range('2016-01-01','2016-6-01',freq='M')
dates
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range?

# %%
tempature=pd.Series([13,15,20,27,29],index=dates)
tempature
# Out:
# 2016-01-31    13
# 2016-02-29    15
# 2016-03-31    20
# 2016-04-30    27
# 2016-05-31    29
# Freq: M, dtype: int64

# %%
temp=pd.Series([13,15,20,27,29],index=[0,2,2,3,4])
temp
# Out:
# 0    13
# 2    15
# 2    20
# 3    27
# 4    29
# dtype: int64

# %% [markdown]
# #### index/slicing

# %%
temp=pd.Series([13,15,20,27,29])
temp
# Out:
# 0    13
# 1    15
# 2    20
# 3    27
# 4    29
# dtype: int64

# %%
temp[0]
# Out:
# 13

# %%
temp[3]
# Out:
# 27

# %%
temp[7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b77ef308038e> in <module>()
# ----> 1 temp[7]
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\indexes\base.py in get_value(self, series, key)
#    1978         try:
#    1979             return self._engine.get_value(s, k,
# -> 1980                                           tz=getattr(series.dtype, 'tz', None))
#    1981         except KeyError as e1:
#    1982             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3332)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3035)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 7

# %%
temp.loc[0]
# Out:
# 13

# %%
temp.loc[-1]  #base on label
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1394                 if key not in ax:
# -> 1395                     error()
#    1396             except TypeError as e:
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in error()
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#
# KeyError: 'the label [-1] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-1208a1c64360> in <module>()
# ----> 1 temp.loc[-1]  #base on label
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1401                 raise
#    1402             except:
# -> 1403                 error()
#    1404
#    1405         return True
#
# C:\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in error()
#    1388                                     "key")
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#    1392             try:
#
# KeyError: 'the label [-1] is not in the [index]'

# %%
temp.iloc[-1]  #position
# Out:
# 29

# %%
temp.iloc[0:3]
# Out:
# 0    13
# 1    15
# 2    20
# dtype: int64

# %%
temp=pd.Series([13,15,20,27,29],index=['M','T','W','T','F'])
temp
# Out:
# M o    13
# T      15
# W      20
# T      27
# F      29
# dtype: int64

# %%
temp['M'] #both position and label work
# Out:
# 13

# %%
temp[0]
# Out:
# 13

# %%
temp['T']
# Out:
# T    15
# T    27
# dtype: int64

# %%
temp.M
# Out:
# 13

# %%
temp.T  #transpose, check with dir(temp)
# Out:
# M    13
# T    15
# W    20
# T    27
# F    29
# dtype: int64

# %% [markdown]
# #### 修改与删除Series中的值

# %%
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
price['wh']=16000
price
# Out:
# wh    16000.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
price.iloc[0]=15280
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
price.append(pd.Series([9500],index=['cd']))  #return a new series
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# cd     9500.0
# dtype: float64

# %%
price['cd']=9500
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# cd     9500.0
# dtype: float64

# %%
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    55689.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
price.set_value('bj',62000) # update inplace
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    62000.0
# gz    28410.0
# nj    27566.3
# cd     9500.0
# dtype: float64

# %%
price
# Out:
# city
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    62000.0
# gz    28410.0
# nj    27566.3
# dtype: float64

# %%
del price['nj']

# %%
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    62000.0
# gz    28410.0
# cd     9500.0
# dtype: float64

# %%
price<50000
# Out:
# wh     True
# sh     True
# hz     True
# bj    False
# gz     True
# cd     True
# dtype: bool

# %%
#filter
price[price<50000]
# Out:
# city
# wh    15280.0
# sh    45888.0
# hz    15692.0
# gz    28410.0
# dtype: float64

# %% [markdown]
# #### summary statistics

# %%
price.min()
# Out:
# 9500.0

# %%
price.max()
# Out:
# 62000.0

# %%
price.median()
# Out:
# 22051.0

# %%
price.describe()
# Out:
# count        6.000000
# mean     29461.666667
# std      20585.747940
# min       9500.000000
# 25%      15383.000000
# 50%      22051.000000
# 75%      41518.500000
# max      62000.000000
# dtype: float64

# %%
price.quantile(0.25)
# Out:
# 15692.0

# %%
price.describe(percentiles=[0.25,0.5])
# Out:
# count        5.000000
# mean     33454.000000
# std      20252.798128
# min      15280.000000
# 25%      15692.000000
# 50%      28410.000000
# max      62000.000000
# dtype: float64

# %%
temp=pd.Series(['hw','apple','vivo','mi','hw','oppo','samsung','vivo'],dtype='category')
temp
# Out:
# 0         hw
# 1      apple
# 2       vivo
# 3         mi
# 4         hw
# 5       oppo
# 6    samsung
# 7       vivo
# dtype: category
# Categories (6, object): [apple, hw, mi, oppo, samsung, vivo]

# %%
print(dir(price))
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_SLICEMAP', '__abs__', '__add__', '__and__', '__array__', '__array_prepare__', '__array_priority__', '__array_wrap__', '__bool__', '__bytes__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__int__', '__invert__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__le__', '__len__', '__long__', '__lt__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__unicode__', '__weakref__', '__xor__', '_accessors', '_add_numeric_operations', '_add_series_only_operations', '_add_series_or_dataframe_operations', '_agg_by_level', '_align_frame', '_align_series', '_allow_index_ops', '_at', '_binop', '_box_item_values', '_can_hold_na', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_percentile', '_check_setitem_copy', '_clear_item_cache', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_dict_for_slice', '_construct_axes_dict_from', '_construct_axes_from_arguments', '_constructor', '_constructor_expanddim', '_constructor_sliced', '_convert', '_create_indexer', '_dir_additions', '_dir_deletions', '_expand_axes', '_from_axes', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_index_resolvers', '_get_item_cache', '_get_numeric_data', '_get_repr', '_get_values', '_get_values_tuple', '_get_with', '_iat', '_iget_item_cache', '_iloc', '_index', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_mgr', '_internal_names', '_internal_names_set', '_is_cached', '_is_datelike_mixed_type', '_is_mixed_type', '_is_numeric_mixed_type', '_is_view', '_ix', '_ixs', '_loc', '_make_cat_accessor', '_make_dt_accessor', '_make_str_accessor', '_maybe_cache_changed', '_maybe_update_cacher', '_metadata', '_needs_reindex_multi', '_protect_consolidate', '_reduce', '_reindex_axes', '_reindex_axis', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_is_copy', '_set_item', '_set_labels', '_set_name', '_set_subtyp', '_set_values', '_set_with', '_set_with_engine', '_setup_axes', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_typ', '_unpickle_series_compat', '_update_inplace', '_validate_dtype', '_values', '_xs', 'abs', 'add', 'add_prefix', 'add_suffix', 'align', 'all', 'any', 'append', 'apply', 'argmax', 'argmin', 'argsort', 'as_blocks', 'as_matrix', 'asfreq', 'asobject', 'asof', 'astype', 'at', 'at_time', 'autocorr', 'axes', 'base', 'between', 'between_time', 'bfill', 'blocks', 'bool', 'clip', 'clip_lower', 'clip_upper', 'combine', 'combine_first', 'compound', 'compress', 'consolidate', 'convert_objects', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'data', 'describe', 'diff', 'div', 'divide', 'dot', 'drop', 'drop_duplicates', 'dropna', 'dtype', 'dtypes', 'duplicated', 'empty', 'eq', 'equals', 'ewm', 'expanding', 'factorize', 'ffill', 'fillna', 'filter', 'first', 'first_valid_index', 'flags', 'floordiv', 'from_array', 'from_csv', 'ftype', 'ftypes', 'ge', 'get', 'get_dtype_counts', 'get_ftype_counts', 'get_value', 'get_values', 'groupby', 'gt', 'hasnans', 'head', 'hist', 'iat', 'idxmax', 'idxmin', 'iget', 'iget_value', 'iloc', 'im ...

# %%
temp.value_counts()
# Out:
# vivo       2
# hw         2
# samsung    1
# oppo       1
# mi         1
# apple      1
# dtype: int64

# %% [markdown]
# #### 向量化操作与广播

# %%
price * 2
# Out:
# wh     30560.0
# sh     91776.0
# hz     31384.0
# bj    124000.0
# gz     56820.0
# cd     19000.0
# dtype: float64

# %%
price+1000 #+,-,/,*
# Out:
# wh    16280.0
# sh    46888.0
# hz    16692.0
# bj    63000.0
# gz    29410.0
# cd    10500.0
# dtype: float64

# %%
np.log(price)
# Out:
# wh     9.634300
# sh    10.733959
# hz     9.660906
# bj    11.034890
# gz    10.254496
# cd     9.159047
# dtype: float64

# %%
li=[2000,3000,3000]
li+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-a3d15009e96a> in <module>()
#       1 li=[2000,3000,3000]
# ----> 2 li+2
#
# TypeError: can only concatenate list (not "int") to list

# %%
li*2
# Out:
# [2000, 3000, 3000, 2000, 3000, 3000]

# %%
s=pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2=pd.Series([10,20,30],index=[2,3,4])
s2
# Out:
# 2    10
# 3    20
# 4    30
# dtype: int64

# %%
s+s2  #NaN 在pandas里面表示不是一个数字
# Out:
# 0     NaN
# 1     NaN
# 2    40.0
# 3    60.0
# 4     NaN
# dtype: float64

# %%
s.apply(float)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
s.astype(int)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int32

# %% [markdown]
# #### iteration

# %%
for num in s:
    print(num)
# Out:
# 10
# 20
# 30
# 40

# %%
40 in s
# Out:
# False

# %%
40 in s.values
# Out:
# True

# %%
0 in s #why? series是key-value存储，所以这里实际是index o
# Out:
# True

# %%
price
# Out:
# wh    15280.0
# sh    45888.0
# hz    15692.0
# bj    62000.0
# gz    28410.0
# cd     9500.0
# dtype: float64

# %%
'bj' in price
# Out:
# True

# %%
li=[10,20,30,40]
40 in li
# Out:
# True

# %%
# looping over dictionary keys and values
for k,v in price.items():
    print(k,v)
# Out:
# wh 15280.0
# sh 45888.0
# hz 15692.0
# bj 62000.0
# gz 28410.0

# %% [markdown]
# # 参考资料

# %% [markdown]
# [pandas series](http://pandas-docs.github.io/pandas-docs-travis/dsintro.html#series)
