# %% [markdown]
# # 课程目标对象
#
# + 想要从事数据科学的人员
# + 数据分析人员
# + 产品经理
# + 网站运维
# + 呼叫中心管理人员
# + 电商运营人员
# + 需要利用数据进行决策的人员

# %% [markdown]
# # 课程内容
#
# + Introduction
# + Pandas基础
# + 数据获取
# + 数据清洗
# + 数据整理
# + 数据探索
# + 数据洞察力
