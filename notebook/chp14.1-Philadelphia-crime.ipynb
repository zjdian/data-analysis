# %% [markdown]
# crime.csv.zip

# %% [markdown]
# ![](./img/crime-day.jpg)

# %% [markdown]
# ![](./img/crime-year.jpg)

# %% [markdown]
# ![](./img/crime-month.jpg)

# %% [markdown]
# ![](./img/crime-by-month-year.png)

# %% [markdown]
# ![](./img/crime-disc.png)

# %% [markdown]
# ![](./img/crime-disc.png)

# %% [markdown]
# ![](./img/crime-map.jpg)
