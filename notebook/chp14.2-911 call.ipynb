# %% [markdown]
# 911.csv.zip

# %% [markdown]
# ![](./img/call-every-month.png)

# %% [markdown]
# ![](./img/call-hour.png)

# %% [markdown]
# ![](./img/call-month.png)

# %% [markdown]
# ![](./img/call-week.png)
